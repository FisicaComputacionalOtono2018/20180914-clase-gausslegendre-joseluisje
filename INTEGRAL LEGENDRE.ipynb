# %%
#VERSION 2 (SIN FUNCIONES ESPECIALES)
import numpy as np
import matplotlib.pyplot as plt
import math
from fractions import Fraction

print("--PROGRAMA QUE RESUELVE EL POLINOMIO DE LEGENDRE DE GRADO ENTERO POSITIVO n Y LO EVALÚA EN UN VALOR REAL x")

aa=float(input("Inserte limite de integracion inferior: "))
bb=float(input("Inserte limite de integracion superior: "))

def pol(x,nn):

  b=float(2)/1000

  d=math.factorial(n)
  e=2**n
  ee=d*e
  fracc=s = Fraction(1, ee)

  p = np.poly1d([1, 0, -1]) #polinomio inicial
  g=p
  h=1
  while h<n: #n-esima potencia del polinomio
    g= g*p
    h=h+1  
  
  k=g
  j=0
  while j<n: #n-esima derivada del polinomio elevado a la n-esima
    k=np.polyder(k)
    j=j+1 

  polfinal=fracc*k #multiplicacion de la fraccion por el polinomio

  derpolf=np.polyder(polfinal) #Derivada

  fxvv=derpolf(xv)
  
  return fxvv



def poli(n):

  b=float(2)/1000

  d=math.factorial(n)
  e=2**n
  ee=d*e
  fracc=s = Fraction(1, ee)

  p = np.poly1d([1, 0, -1]) #polinomio inicial
  g=p
  h=1
  while h<n: #n-esima potencia del polinomio
    g= g*p
    h=h+1  
  
  k=g
  j=0
  while j<n: #n-esima derivada del polinomio elevado a la n-esima
    k=np.polyder(k)
    j=j+1 

  polfinal=fracc*k #multiplicacion de la fraccion por el polinomio

  derpolf=np.polyder(polfinal) #Derivada
  
  return derpolf



def f(x):
  a=x**3+2*x**2
  return a


qq=polinomio*polinomio

qqx=qq(xv)

ww=1-xv**2

rr=qqx*ww

w=float(2)/rr #derivada al cuadradado evaluada en x
aaa=math.sqrt(float(1)/3)
xi=[-aaa,aaa]
q1=float(bb-aa)/2
q2=float(aa+bb)/2
n1=2
plim=(poli(n1))**2

cor=[]
for i in xi:
  q3=q1*float(i)+q2
  f1=f(q3)
  tl=9*i**2
  f2=float(2)/(tl*(1-i**2))
  p1=f2*f1
  cor.append(p1)
sumaa=sum(cor)
finall=sumaa*float(q1)

print("la integral es: ", finall)
# Out:
# --PROGRAMA QUE RESUELVE EL POLINOMIO DE LEGENDRE DE GRADO ENTERO POSITIVO n Y LO EVALÚA EN UN VALOR REAL x
# Inserte limite de integracion inferior: 1
# Inserte limite de integracion superior: 5
# la integral es:  238.66666666666666
